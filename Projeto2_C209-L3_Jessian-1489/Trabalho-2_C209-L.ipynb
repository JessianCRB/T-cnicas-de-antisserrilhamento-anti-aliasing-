# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
img1 = Image.open("boku-no-hero.jpg")

# %%
plt.imshow(img1)

# %%
img2 = img1.resize((1920,1080))
plt.imshow(img2)

# %%
img3 = img1.resize((1920,1080),Image.ANTIALIAS)
plt.imshow(img3)
